# %% [markdown]
# <a href="https://colab.research.google.com/github/pkdeeshna/AI-Image-Detector-Gradio/blob/main/AI_detector_pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pillow transformers torch gradio grad-cam

# %%
from transformers import pipeline
import gradio as gr
from PIL import Image
import requests
from io import BytesIO

# %%
pipe=pipeline("image-classification",
              model="umm-maybe/AI-image-detector")
# Out:
# config.json:   0%|          | 0.00/937 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/348M [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/240 [00:00<?, ?B/s]
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# Device set to use cuda:0
# model.safetensors:   0%|          | 0.00/347M [00:00<?, ?B/s]

# %%
def detect_ai(image):
  result=pipe(image)
  label=result[0]['label']
  confidence=result[0]['score']*100
  return f"{label}: {confidence:.1f}% confident"

# %%
demo=gr.Interface(fn=detect_ai,
                  inputs=gr.Image(type="pil"),
                  outputs="text")
demo.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://653442876816822f3a.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://653442876816822f3a.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
